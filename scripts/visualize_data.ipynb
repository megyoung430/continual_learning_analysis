# %%
import sys
sys.path.insert(0,'/Users/megyoung/continual_learning_analysis/bpodautopy/bpodautopy')
sys.path.insert(0,'/Users/megyoung/continual_learning_analysis/')
from db import Engine, Connection
from pathlib import Path
import pandas as pd
import numpy as np
import json

import src.database.database_fxns as dtb

dbc = Connection()
dbe = Engine()

# %%
task_name = "continual_learning_fm"
subjids = ["JLI-R-0049", "JLI-R-0050", "JLI-R-0051", "JLI-R-0052", "JLI-R-0053", "JLI-R-0054", "JLI-R-0055", "JLI-R-0056"]

# %%
sess_id = dtb.get_sess_ids(dbe, task_name, subjid="JLI-R-0050", sessiondate='07/16/24', settings_name=None, just_ids=True)
dtb.get_session_df(dbe, sess_id[0])
# Out:
#      trialid  sessid                  trialtime  trialnum  hit  viol  reward  \
# 0    7089921   37691 2024-07-16 10:46:38.554700         1  0.0     1     0.0
# 1    7089934   37691 2024-07-16 10:46:49.181600         2  1.0     0    20.0
# 2    7089944   37691 2024-07-16 10:46:55.600000         3  1.0     0     0.0
# 3    7089959   37691 2024-07-16 10:47:03.874600         4  0.0     1     0.0
# 4    7089967   37691 2024-07-16 10:47:11.452700         5  0.0     0     0.0
# ..       ...     ...                        ...       ...  ...   ...     ...
# 506  7095525   37691 2024-07-16 12:05:59.388000       507  0.0     1     0.0
# 507  7095537   37691 2024-07-16 12:06:10.005100       508  NaN     1     0.0
# 508  7095545   37691 2024-07-16 12:06:22.475400       509  1.0     0    20.0
# 509  7095559   37691 2024-07-16 12:06:31.698600       510  0.0     1     0.0
# 510  7095569   37691 2024-07-16 12:06:44.616300       511  1.0     0    20.0
#
#        RT      subjid  n_pokes  \
# ...
